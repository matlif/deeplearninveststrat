# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from tensorflow.python.ops import rnn, rnn_cell
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from collections import deque
from sklearn import preprocessing
# Out:
# C:\Users\jeryf\Anaconda3\envs\tensorflow_env\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
df = pd.read_csv('autoencoder4factors.csv', index_col=0)
df.drop('timestemp', axis=1, inplace=True)

# %%
seq_len = 12

# %%
df_temp = df[df['gvkey']==1209].drop('gvkey', axis=1)

min_max_scaler = preprocessing.MinMaxScaler()
df_temp = pd.DataFrame(min_max_scaler.fit_transform(df_temp), columns=df_temp.columns.values)
df_temp.ffill(inplace=True)

# %%
X_list = []
Y_list = []
for i in range(len(df_temp)-seq_len-4):
    X_list += [df_temp.iloc[i:i+seq_len].values]
    Y_list += [df_temp.iloc[i+seq_len+4, -1]]
    
X = np.array(X_list)
Y = np.array(Y_list)

# First 72 quarters are for training
X_train = X[:int(len(X)*0.7)]
X_test = X[int(len(X)*0.7):]

Y_train = Y[:int(len(X)*0.7)]
Y_test = Y[int(len(X)*0.7):]

# %%
tf.reset_default_graph()

hm_epochs = 100
n_classes = 1
n_batches = 4
batch_size = X_train.shape[0]/n_batches
chunk_size = X_train.shape[2]
rnn_size = 64

x = tf.placeholder('float', [None, seq_len, chunk_size])
y = tf.placeholder('float')

def recurrent_neural_network(x):
    layer = {'weights':tf.Variable(tf.random_normal([rnn_size,n_classes])),
             'biases':tf.Variable(tf.random_normal([n_classes]))}

#     layer = {'weights':tf.Variable(np.random.normal(size=(rnn_size,n_classes)).astype('float32')),
#              'biases':tf.Variable(tf.random_normal([n_classes]))}

    x = tf.transpose(x, [1,0,2])
    x = tf.reshape(x, [-1, chunk_size])
    x = tf.split(x, seq_len, 0)

    lstm_cell = rnn_cell.BasicLSTMCell(rnn_size, state_is_tuple=True)
    lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm_cell, input_keep_prob=1, output_keep_prob=1)
    outputs, states = rnn.static_rnn(lstm_dropout, x, dtype=tf.float32)

    output = tf.matmul(outputs[-1],layer['weights']) + layer['biases'] # softmax layer

#     attention_weights = tf.Variable(tf.random_normal([seq_len]))
#     attention_ouput = tf.reduce_sum(tf.multiply(tf.convert_to_tensor(outputs) , tf.Variable(tf.random_normal([seq_len]))[:, tf.newaxis, tf.newaxis]), axis=0)
#     output = tf.matmul(attention_ouput,layer['weights']) + layer['biases'] # softmax layer

    return output

def train_neural_network(x):
    prediction = recurrent_neural_network(x)  
    cost = tf.losses.mean_squared_error(predictions=prediction, labels=y)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
    
    
    with tf.Session() as sess:
        sess.run(tf.initialize_all_variables())

        for epoch in range(hm_epochs):
            epoch_loss = 0
            for i in range(n_batches):
                epoch_x = X_train[i*int(batch_size):(i+1)*int(batch_size)]
                epoch_y = Y_train[i*int(batch_size):(i+1)*int(batch_size)]

                _, c = sess.run([optimizer, cost], feed_dict={x: epoch_x, y: epoch_y})
                epoch_loss += c

            print('Epoch', epoch, 'completed out of',hm_epochs,'loss:', np.mean(epoch_loss))
    
        pred_train = sess.run(prediction, feed_dict={x: X_train.astype('float32')})[:,0]
        pred_test = sess.run(prediction, feed_dict={x: X_test.astype('float32')})[:,0]
        
        print('Testing MAE:', np.mean(np.abs(pred_test-Y_test)))
        print('Testing MSE:', np.mean((pred_test-Y_test)**2))
        
        plt.style.use('ggplot')

        fig = plt.figure(figsize=(12, 6))
        ax = fig.add_axes([0.1, 0.1, 0.6, 0.75])
        ax.plot(Y_train, label='True values', color='blue')
        ax.plot(X_train[:, -1, -1], label='No Model', linestyle='--', color='black')
        ax.plot(pred_train, label='RNN', color='red')
        ax.legend()
        plt.title('Training Predictions')
        plt.show()
        
        fig = plt.figure(figsize=(12, 6))
        ax = fig.add_axes([0.1, 0.1, 0.6, 0.75])
        ax.plot(Y_test, label='True values', color='blue')
        ax.plot(X_test[:, -1, -1], label='No Model', linestyle='--', color='black')
        ax.plot(pred_test, label='RNN', color='red')
        ax.legend()
        plt.title('Testing Predictions')
        plt.show()

train_neural_network(x)
# Out:
# Epoch 0 completed out of 100 loss: 0.6391403577290475
# Epoch 1 completed out of 100 loss: 0.06746341241523623
# Epoch 2 completed out of 100 loss: 0.1122895060107112
# Epoch 3 completed out of 100 loss: 0.04039693437516689
# Epoch 4 completed out of 100 loss: 0.057180666364729404
# Epoch 5 completed out of 100 loss: 0.0325862723402679
# Epoch 6 completed out of 100 loss: 0.03674336150288582
# Epoch 7 completed out of 100 loss: 0.03516786824911833
# Epoch 8 completed out of 100 loss: 0.03321690228767693
# Epoch 9 completed out of 100 loss: 0.02675462467595935
# Epoch 10 completed out of 100 loss: 0.02749097580090165
# Epoch 11 completed out of 100 loss: 0.02526659518480301
# Epoch 12 completed out of 100 loss: 0.02583028911612928
# Epoch 13 completed out of 100 loss: 0.024906958220526576
# Epoch 14 completed out of 100 loss: 0.023911367636173964
# Epoch 15 completed out of 100 loss: 0.0236227884888649
# Epoch 16 completed out of 100 loss: 0.02323961420916021
# Epoch 17 completed out of 100 loss: 0.02297728939447552
# Epoch 18 completed out of 100 loss: 0.022724913666024804
# Epoch 19 completed out of 100 loss: 0.02242833178024739
# Epoch 20 completed out of 100 loss: 0.022202860563993454
# Epoch 21 completed out of 100 loss: 0.021993489935994148
# Epoch 22 completed out of 100 loss: 0.021829536883160472
# Epoch 23 completed out of 100 loss: 0.02165607421193272
# Epoch 24 completed out of 100 loss: 0.021530858939513564
# Epoch 25 completed out of 100 loss: 0.021419422701001167
# Epoch 26 completed out of 100 loss: 0.021297078114002943
# Epoch 27 completed out of 100 loss: 0.02120003046002239
# Epoch 28 completed out of 100 loss: 0.021110699279233813
# Epoch 29 completed out of 100 loss: 0.021024278830736876
# Epoch 30 completed out of 100 loss: 0.020949069876223803
# Epoch 31 completed out of 100 loss: 0.020881900913082063
# Epoch 32 completed out of 100 loss: 0.020816076430492103
# Epoch 33 completed out of 100 loss: 0.020758767379447818
# Epoch 34 completed out of 100 loss: 0.020703997113741934
# Epoch 35 completed out of 100 loss: 0.020652068313211203
# Epoch 36 completed out of 100 loss: 0.02060521289240569
# Epoch 37 completed out of 100 loss: 0.020560203702189028
# Epoch 38 completed out of 100 loss: 0.020517959375865757
# Epoch 39 completed out of 100 loss: 0.02047867455985397
# Epoch 40 completed out of 100 loss: 0.020440495805814862
# Epoch 41 completed out of 100 loss: 0.020404806709848344
# Epoch 42 completed out of 100 loss: 0.020370809477753937
# Epoch 43 completed out of 100 loss: 0.02033820131327957
# Epoch 44 completed out of 100 loss: 0.020307505503296852
# Epoch 45 completed out of 100 loss: 0.020277870818972588
# Epoch 46 completed out of 100 loss: 0.020249620312824845
# Epoch 47 completed out of 100 loss: 0.020222589490003884
# Epoch 48 completed out of 100 loss: 0.020196531899273396
# Epoch 49 completed out of 100 loss: 0.020171679207123816
# Epoch 50 completed out of 100 loss: 0.02014772337861359
# Epoch 51 completed out of 100 loss: 0.020124749979004264
# Epoch 52 completed out of 100 loss: 0.02010264340788126
# Epoch 53 completed out of 100 loss: 0.0200813451083377
# Epoch 54 completed out of 100 loss: 0.020060892798937857
# Epoch 55 completed out of 100 loss: 0.020041120937094092
# Epoch 56 completed out of 100 loss: 0.020022097043693066
# Epoch 57 completed out of 100 loss: 0.020003744517453015
# Epoch 58 completed out of 100 loss: 0.01998601737432182
# Epoch 59 completed out of 100 loss: 0.01996891456656158
# Epoch 60 completed out of 100 loss: 0.01995237311348319
# Epoch 61 completed out of 100 loss: 0.019936414319090545
# Epoch 62 completed out of 100 loss: 0.019920959952287376
# Epoch 63 completed out of 100 loss: 0.019906018511392176
# Epoch 64 completed out of 100 loss: 0.019891554955393076
# Epoch 65 completed out of 100 loss: 0.019877562182955444
# Epoch 66 completed out of 100 loss: 0.019863988156430423
# Epoch 67 completed out of 100 loss: 0.01985083904583007
# Epoch 68 completed out of 100 loss: 0.019838094478473067
# Epoch 69 completed out of 100 loss: 0.01982571987900883
# Epoch 70 completed out of 100 loss: 0.019813717808574438
# Epoch 71 completed out of 100 loss: 0.01980206905864179
# Epoch 72 completed out of 100 loss: 0.019790743477642536
# Epoch 73 completed out of 100 loss: 0.019779749680310488
# Epoch 74 completed out of 100 loss: 0.019769051112234592
# Epoch 75 completed out of 100 loss: 0.019758644746616483
# Epoch 76 completed out of 100 loss: 0.019748520804569125
# Epoch 77 completed out of 100 loss: 0.01973865949548781
# Epoch 78 completed out of 100 loss: 0.019729066756553948
# Epoch 79 completed out of 100 loss: 0.019719716510735452
# Epoch 80 completed out of 100 loss: 0.019710603985004127
# Epoch 81 completed out of 100 loss: 0.019701712764799595
# Epoch 82 completed out of 100 loss: 0.019693038892000914
# Epoch 83 completed out of 100 loss: 0.01968456932809204
# Epoch 84 completed out of 100 loss: 0.019676312571391463
# Epoch 85 completed out of 100 loss: 0.019668241147883236
# Epoch 86 completed out of 100 loss: 0.01966036017984152
# Epoch 87 completed out of 100 loss: 0.019652642426081002
# Epoch 88 completed out of 100 loss: 0.01964511547703296
# Epoch 89 completed out of 100 loss: 0.019637726712971926
# Epoch 90 completed out of 100 loss: 0.01963052526116371
# Epoch 91 completed out of 100 loss: 0.019623455358669162
# Epoch 92 completed out of 100 loss: 0.019616557634435594
# Epoch 93 completed out of 100 loss: 0.01960976014379412
# Epoch 94 completed out of 100 loss: 0.019603151828050613
# Epoch 95 completed out of 100 loss: 0.019596622441895306
# Epoch 96 completed out of 100 loss: 0.01959028490819037
# Epoch 97 completed out of 100 loss: 0.019583983812481165
# Epoch 98 completed out of 100 loss: 0.019577918224968016
# Epoch 99 completed out of 100 loss: 0.019571821088902652
# Testing MAE: 0.15323413982925535
# Testing MSE: 0.03778313583280211
