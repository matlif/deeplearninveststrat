# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from tensorflow.python.ops import rnn, rnn_cell
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from collections import deque
from sklearn import preprocessing

# %%
df = pd.read_csv('autoencoder4factors.csv', index_col=0)
df.drop('timestemp', axis=1, inplace=True)

# %%
seq_len = 12

df_temp = df[df['gvkey']==1209].drop('gvkey', axis=1)

min_max_scaler = preprocessing.MinMaxScaler()
df_temp = pd.DataFrame(min_max_scaler.fit_transform(df_temp), columns=df_temp.columns.values)
df_temp.ffill(inplace=True)

# %%
X_list = []
Y_list = []
for i in range(len(df_temp)-seq_len-4):
    X_list += [df_temp.iloc[i:i+seq_len].values]
    Y_list += [df_temp.iloc[i+seq_len+4, -1]]
    
X = np.array(X_list)
Y = np.array(Y_list)

# First 72 quarters are for training
X_train = X[:int(len(X)*0.7)]
X_test = X[int(len(X)*0.7):]

Y_train = Y[:int(len(X)*0.7)]
Y_test = Y[int(len(X)*0.7):]

# %%
tf.reset_default_graph()

hm_epochs = 100
n_classes = 1
n_batches = 4
batch_size = X_train.shape[0]/n_batches
chunk_size = X_train.shape[2]
rnn_size = 64
num_layers = 2

x = tf.placeholder('float', [None, seq_len, chunk_size])
y = tf.placeholder('float')

def recurrent_neural_network(x):
    layer = {'weights':tf.Variable(tf.random_normal([rnn_size,n_classes])),
             'biases':tf.Variable(tf.random_normal([n_classes]))}

#     layer = {'weights':tf.Variable(np.random.normal(size=(rnn_size,n_classes)).astype('float32')),
#              'biases':tf.Variable(tf.random_normal([n_classes]))}

    x = tf.transpose(x, [1,0,2])
    x = tf.reshape(x, [-1, chunk_size])
    x = tf.split(x, seq_len, 0)
    
    lstm_cells = []
    for li in range(num_layers):
        lstm_cell = tf.contrib.rnn.LSTMCell(rnn_size, state_is_tuple = True, initializer= tf.contrib.layers.xavier_initializer())
        dropout_cell = tf.contrib.rnn.DropoutWrapper(lstm_cell, input_keep_prob=1.0, output_keep_prob=1.0)
        lstm_cells.append(dropout_cell)
    multi_cell = tf.contrib.rnn.MultiRNNCell(lstm_cells)


    #lstm_cell = [tf.contrib.rnn.LSTMCell(rnn_size, state_is_tuple = True, initializer= tf.contrib.layers.xavier_initializer()) for li in range(num_layers)]
    #multi_cell = tf.contrib.rnn.MultiRNNCell(lstm_cell)
    
    
    outputs, states = rnn.static_rnn(multi_cell, x, dtype=tf.float32)
    
    
    output = tf.matmul(outputs[-1],layer['weights']) + layer['biases'] # softmax layer

#     attention_weights = tf.Variable(tf.random_normal([seq_len]))
#     attention_ouput = tf.reduce_sum(tf.multiply(tf.convert_to_tensor(outputs) , tf.Variable(tf.random_normal([seq_len]))[:, tf.newaxis, tf.newaxis]), axis=0)
#     output = tf.matmul(attention_ouput,layer['weights']) + layer['biases'] # softmax layer

    return output

def train_neural_network(x):
    prediction = recurrent_neural_network(x)  
    cost = tf.losses.mean_squared_error(predictions=prediction, labels=y)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
    
    
    with tf.Session() as sess:
        sess.run(tf.initialize_all_variables())

        for epoch in range(hm_epochs):
            epoch_loss = 0
            for i in range(n_batches):
                epoch_x = X_train[i*int(batch_size):(i+1)*int(batch_size)]
                epoch_y = Y_train[i*int(batch_size):(i+1)*int(batch_size)]

                _, c = sess.run([optimizer, cost], feed_dict={x: epoch_x, y: epoch_y})
                epoch_loss += c

            print('Epoch', epoch, 'completed out of',hm_epochs,'loss:', np.mean(epoch_loss))
    
        pred_train = sess.run(prediction, feed_dict={x: X_train.astype('float32')})[:,0]
        pred_test = sess.run(prediction, feed_dict={x: X_test.astype('float32')})[:,0]
        
        print('Testing MAE:', np.mean(np.abs(pred_test-Y_test)))
        print('Testing MSE:', np.mean((pred_test-Y_test)**2))
        
        plt.style.use('ggplot')

        fig = plt.figure(figsize=(12, 6))
        ax = fig.add_axes([0.1, 0.1, 0.6, 0.75])
        ax.plot(Y_train, label='True values', color='blue')
        ax.plot(X_train[:, -1, -1], label='No Model', linestyle='--', color='black')
        ax.plot(pred_train, label='RNN', color='red')
        ax.legend()
        plt.title('Training Predictions')
        plt.show()
        
        fig = plt.figure(figsize=(12, 6))
        ax = fig.add_axes([0.1, 0.1, 0.6, 0.75])
        ax.plot(Y_test, label='True values', color='blue')
        ax.plot(X_test[:, -1, -1], label='No Model', linestyle='--', color='black')
        ax.plot(pred_test, label='RNN', color='red')
        ax.legend()
        plt.title('Testing Predictions')
        plt.show()

train_neural_network(x)
# Out:
# Epoch 0 completed out of 100 loss: 0.5209122579544783
# Epoch 1 completed out of 100 loss: 0.10902903275564313
# Epoch 2 completed out of 100 loss: 0.114980811602436
# Epoch 3 completed out of 100 loss: 0.08168639685027301
# Epoch 4 completed out of 100 loss: 0.026676942827180028
# Epoch 5 completed out of 100 loss: 0.050711228512227535
# Epoch 6 completed out of 100 loss: 0.032630959525704384
# Epoch 7 completed out of 100 loss: 0.025229924474842846
# Epoch 8 completed out of 100 loss: 0.023948960471898317
# Epoch 9 completed out of 100 loss: 0.02888773859012872
# Epoch 10 completed out of 100 loss: 0.02341359423007816
# Epoch 11 completed out of 100 loss: 0.022532385541126132
# Epoch 12 completed out of 100 loss: 0.021950698806904256
# Epoch 13 completed out of 100 loss: 0.02147961058653891
# Epoch 14 completed out of 100 loss: 0.020818476332351565
# Epoch 15 completed out of 100 loss: 0.020892780739814043
# Epoch 16 completed out of 100 loss: 0.020383385592140257
# Epoch 17 completed out of 100 loss: 0.020278407377190888
# Epoch 18 completed out of 100 loss: 0.02035039709880948
# Epoch 19 completed out of 100 loss: 0.02007337403483689
# Epoch 20 completed out of 100 loss: 0.02007455041166395
# Epoch 21 completed out of 100 loss: 0.02001892344560474
# Epoch 22 completed out of 100 loss: 0.019947032094933093
# Epoch 23 completed out of 100 loss: 0.01989621587563306
# Epoch 24 completed out of 100 loss: 0.01984507031738758
# Epoch 25 completed out of 100 loss: 0.019803017494268715
# Epoch 26 completed out of 100 loss: 0.019777276553213596
# Epoch 27 completed out of 100 loss: 0.019746941165067255
# Epoch 28 completed out of 100 loss: 0.019726149854250252
# Epoch 29 completed out of 100 loss: 0.019703545491211116
# Epoch 30 completed out of 100 loss: 0.019688780419528484
# Epoch 31 completed out of 100 loss: 0.019673458416946232
# Epoch 32 completed out of 100 loss: 0.019658965058624744
# Epoch 33 completed out of 100 loss: 0.01964577939361334
# Epoch 34 completed out of 100 loss: 0.01963443448767066
# Epoch 35 completed out of 100 loss: 0.019624801469035447
# Epoch 36 completed out of 100 loss: 0.019615910947322845
# Epoch 37 completed out of 100 loss: 0.019607950816862285
# Epoch 38 completed out of 100 loss: 0.019600910134613514
# Epoch 39 completed out of 100 loss: 0.01959428284317255
# Epoch 40 completed out of 100 loss: 0.01958824321627617
# Epoch 41 completed out of 100 loss: 0.01958201581146568
# Epoch 42 completed out of 100 loss: 0.01957694406155497
# Epoch 43 completed out of 100 loss: 0.019571531331166625
# Epoch 44 completed out of 100 loss: 0.019567097071558237
# Epoch 45 completed out of 100 loss: 0.019562308909371495
# Epoch 46 completed out of 100 loss: 0.019558433908969164
# Epoch 47 completed out of 100 loss: 0.01955416880082339
# Epoch 48 completed out of 100 loss: 0.019550317199900746
# Epoch 49 completed out of 100 loss: 0.01954650564584881
# Epoch 50 completed out of 100 loss: 0.019542826572433114
# Epoch 51 completed out of 100 loss: 0.01953930698800832
# Epoch 52 completed out of 100 loss: 0.01953577413223684
# Epoch 53 completed out of 100 loss: 0.019532504840753973
# Epoch 54 completed out of 100 loss: 0.019529174431227148
# Epoch 55 completed out of 100 loss: 0.019525897572748363
# Epoch 56 completed out of 100 loss: 0.019522767164744437
# Epoch 57 completed out of 100 loss: 0.019519590539857745
# Epoch 58 completed out of 100 loss: 0.019516471540555358
# Epoch 59 completed out of 100 loss: 0.019513447186909616
# Epoch 60 completed out of 100 loss: 0.0195104016456753
# Epoch 61 completed out of 100 loss: 0.019507384626194835
# Epoch 62 completed out of 100 loss: 0.019504456548020244
# Epoch 63 completed out of 100 loss: 0.019501496572047472
# Epoch 64 completed out of 100 loss: 0.019498539622873068
# Epoch 65 completed out of 100 loss: 0.019495705608278513
# Epoch 66 completed out of 100 loss: 0.019492807681672275
# Epoch 67 completed out of 100 loss: 0.01948988123331219
# Epoch 68 completed out of 100 loss: 0.019487183541059494
# Epoch 69 completed out of 100 loss: 0.019484331947751343
# Epoch 70 completed out of 100 loss: 0.01948135974816978
# Epoch 71 completed out of 100 loss: 0.019478892325423658
# Epoch 72 completed out of 100 loss: 0.01947608741465956
# Epoch 73 completed out of 100 loss: 0.019472853047773242
# Epoch 74 completed out of 100 loss: 0.019470922299660742
# Epoch 75 completed out of 100 loss: 0.019468282465822995
# Epoch 76 completed out of 100 loss: 0.01946404715999961
# Epoch 77 completed out of 100 loss: 0.01946350187063217
# Epoch 78 completed out of 100 loss: 0.019462048774585128
# Epoch 79 completed out of 100 loss: 0.01945452729705721
# Epoch 80 completed out of 100 loss: 0.019457396818324924
# Epoch 81 completed out of 100 loss: 0.019466089666821063
# Epoch 82 completed out of 100 loss: 0.019450712483376265
# Epoch 83 completed out of 100 loss: 0.01946002314798534
# Epoch 84 completed out of 100 loss: 0.019580425694584846
# Epoch 85 completed out of 100 loss: 0.019562003784812987
# Epoch 86 completed out of 100 loss: 0.019663031329400837
# Epoch 87 completed out of 100 loss: 0.021289093419909477
# Epoch 88 completed out of 100 loss: 0.02106137911323458
# Epoch 89 completed out of 100 loss: 0.025598698877729475
# Epoch 90 completed out of 100 loss: 0.0468449373729527
# Epoch 91 completed out of 100 loss: 0.03924628463573754
# Epoch 92 completed out of 100 loss: 0.14015928283333778
# Epoch 93 completed out of 100 loss: 0.2747155111283064
# Epoch 94 completed out of 100 loss: 0.11196482134982944
# Epoch 95 completed out of 100 loss: 0.06311619840562344
# Epoch 96 completed out of 100 loss: 0.02562995906919241
# Epoch 97 completed out of 100 loss: 0.04033383296336979
# Epoch 98 completed out of 100 loss: 0.024643539683893323
# Epoch 99 completed out of 100 loss: 0.025059815729036927
# Testing MAE: 0.07195445423453264
# Testing MSE: 0.016091824456546982
